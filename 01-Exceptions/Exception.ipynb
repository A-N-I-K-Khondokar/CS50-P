# %%
print("Hello, workd)
# Out:
#   File "/tmp/ipykernel_1693/1600260112.py", line 1
#     print("Hello, workd)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x=int(input("what x? "))
print(f"x is {x}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1693/3198219730.py in <cell line: 0>()
# ----> 1 x=int(input("what x? "))
#       2 print(f"x is {x}")
#
# ValueError: invalid literal for int() with base 10: 'r'

# %% [markdown]
# try **keyworkd** and except **keyword**

# %%
try:
    x=int(input("what x? "))
    print(f"x is {x}")
except ValueError:
    print("x is not an integer")
# Out:
# x is not an integer

# %% [markdown]
# ## NameError

# %% [markdown]
# else for catch another exception

# %%
try:
    x=int(input("what x? "))
except ValueError:
    print("x is not an integer")

print(f"x is {x}")
# Out:
# x is not an integer
# x is 50
